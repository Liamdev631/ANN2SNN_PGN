# %%
from datasets import load_dataset
ds = load_dataset("imagenet-1k")
train_ds = ds["train"]
# Out:
# ---------------------------------------------------------------------------
# DatasetNotFoundError                      Traceback (most recent call last)
# Cell In[1], line 2
#       1 from datasets import load_dataset
# ----> 2 ds = load_dataset("imagenet-1k")
#       3 train_ds = ds["train"]
#
# File ~/anaconda3/envs/torchenv/lib/python3.12/site-packages/datasets/load.py:2074, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2069 verification_mode = VerificationMode(
#    2070     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2071 )
#    2073 # Create a dataset builder
# -> 2074 builder_instance = load_dataset_builder(
#    2075     path=path,
#    2076     name=name,
#    2077     data_dir=data_dir,
# ...
